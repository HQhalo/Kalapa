# %%
from loadData import *
from preProcessing import *
pd.set_option("max_columns",None)
pd.set_option("max_rows",100)

# %%
train= load_train_dataset()
test = load_test_dataset()
# Out:
# /Users/hq/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
preProce = PreProcessing()
preProce.fit(train)
preProce.drop_null_row()

# %%
preProce.dataset.id.value_counts()
# Out:
# 4094     1
# 14994    1
# 661      1
# 6806     1
# 4759     1
#         ..
# 15693    1
# 21840    1
# 23889    1
# 17746    1
# 0        1
# Name: id, Length: 23332, dtype: int64

# %%
preProce.cutFIELD_3()

# %%
preProce.dataset
# Out:
#         id  label               province               district  age_source1  \
# 1        1      0          Tỉnh Đồng Nai     Thành phố Biên Hòa         44.0
# 2        2      0          Tỉnh Đồng Nai       Huyện Long Thành         30.0
# 3        3      0       Tỉnh Tuyên Quang  Thành phố Tuyên Quang         43.0
# 4        4      0  Thành phố Hồ Chí Minh                 Quận 1         21.0
# 6        6      0                    NaN                    NaN          NaN
# ...    ...    ...                    ...                    ...          ...
# 242    242      0                    NaN                    NaN          NaN
# 437    437      0                    NaN                    NaN          NaN
# 684    684      0                    NaN                    NaN          NaN
# 1679  1679      1                    NaN                    NaN          NaN
# 3984  3984      1                    NaN                    NaN          NaN
#
#       age_source2       maCv  FIELD_1  FIELD_2 FIELD_3  FIELD_4  FIELD_5  \
# 1            44.0        NaN        1      0.0     NaN      1.0      1.0
# 2            30.0  Công nhân        0      1.0       8      1.0      4.0
# 3             NaN        NaN        0      1.0      10      1.0      1.0
# 4            21.0        NaN        0      1.0       3      0.0      2.0
# 6            28.0       2983        1      0.0     NaN      0.0      0.0
# ...           ...        ...      ...      ...     ...      ...      ...
# 242           NaN        NaN        1      NaN     NaN      NaN      NaN
# 437           NaN        NaN        0      NaN     NaN      NaN      NaN
# 684           NaN        NaN        1      NaN     NaN      NaN      NaN
# 1679          NaN        NaN        0      NaN     NaN      NaN      NaN
# 3984          NaN        NaN        1      NaN     NaN      NaN      NaN
#
#       FIELD_6             FIELD_7 FIELD_8 FIELD_9 FIELD_10  FIELD_11 FIELD_12  \
# 1         1.0  ['GD', 'GD', 'TE']    MALE      GD       T1      12.0      NaN
# 2         0.0  ['DN', 'HN', 'DN']  FEMALE      DN       T1      12.0        0
# 3         0.0        ['CH', 'TQ']     NaN     NaN      NaN       NaN      NaN
# 4         0.0        ['SV', 'GD']    MALE      GD       T1      12.0      NaN
# 6         0.0                 NaN    MALE      DN       GH       3.0      NaN
# ...       ...                 ...     ...     ...      ...       ...      ...
# 242       NaN                 NaN     NaN     NaN      NaN       NaN      NaN
# 437       NaN                 NaN     NaN     NaN      NaN       NaN      NaN
# 684       NaN                 NaN     NaN     NaN      NaN       NaN      NaN
# 1679      NaN                 NaN     NaN     NaN      NaN       NaN      NaN
# 3984      NaN                 NaN     NaN     NaN      NaN       NaN      NaN
#
#      FIELD_13  FIELD_14  FIELD_15  FIELD_16 FIELD_17 FIELD_18 FIELD_19  \
# 1          BI         0         0       2.0       G8     True     True
# 2          YN         0         0       1.0      NaN    False    False
# 3         NaN         1         1       NaN      NaN      NaN      NaN
# 4          BI         0         0       1.0       G8     True     True
# 6          TG         1         1       1.0      NaN     True     True
# ...       ...       ...       ...       ...      ...      ...      ...
# 242       NaN         1         1       NaN      NaN      NaN      NaN
# 437       NaN         1         1       NaN      NaN      NaN      NaN
# 684       NaN         1         1       NaN      NaN      NaN      NaN
# 1679      NaN         1         1       NaN      NaN      NaN      NaN
# 3984      NaN         1         1       NaN      NaN      NaN      NaN
#
#      FIELD_20  FIELD_21  FIELD_22 FIELD_23 FIELD_24 FIELD_25 FIELD_26  \
# 1        True       1.0       4.0     True      NaN    False    False
# 2       False       1.0      54.0     True      NaN     True     True
# 3         NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 4        True       1.0      24.0     True      NaN    False    False
# 6       False       1.0       0.0     True      NaN    False    False
# ...       ...       ...       ...      ...      ...      ...      ...
# 242       NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 437       NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 684       NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 1679      NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 3984      NaN       NaN       NaN      NaN      NaN      NaN      NaN
#
#      FIELD_27 FIELD_28 FIELD_29 FIELD_30 FIELD_31  FIELD_32  FIELD_33  \
# 1        True     True      NaN      NaN      NaN         0         1
# 2        True     True    False    False    False         0         1
# 3         NaN      NaN      NaN      NaN      NaN         1         1
# 4        True     True      NaN      NaN      NaN         0         1
# 6        True     True      NaN      NaN      NaN         0         1
# ...       ...      ...      ...      ...      ...       ...       ...
# 242       NaN      NaN      NaN      NaN      NaN         1         1
# 437       NaN      NaN      NaN      NaN      NaN         1         1
# 684       NaN      NaN      NaN      NaN      NaN         1         1
# 1679      NaN      NaN      NaN      NaN      NaN         1         1
# 3984      NaN      NaN      NaN      NaN      NaN         1         1
#
#       FIELD_34 FIELD_35 FIELD_36 FIELD_37 FIELD_38 FIELD_39 FIELD_40 FIELD_41  \
# 1            0     Zero    False     True    False       VN      NaN        V
# 2            1     Zero    False     True    False      NaN      NaN        I
# 3            1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4            0     Zero    False     True    False      NaN      NaN        V
# 6            0     Four     True     True    False      NaN      NaN        I
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 242          1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 437          1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 684          1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1679         1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3984         1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      FIELD_42 FIELD_43 FIELD_44  FIELD_45  FIELD_46  FIELD_47  FIELD_48  \
# 1        Zezo      NaN      One       1.0         0     False     False
# 2        Zezo      NaN      Two       2.0         1      True      True
# 3         NaN      NaN      NaN       NaN         0     False      True
# 4        Zezo      NaN      One       1.0         1      True      True
# 6        Zezo      NaN      One       1.0         1     False     False
# ...       ...      ...      ...       ...       ...       ...       ...
# 242       NaN      NaN      NaN       NaN         0     False     False
# 437       NaN      NaN      NaN       NaN         0      True      True
# 684       NaN      NaN      NaN       NaN         0      True      True
# 1679      NaN      NaN      NaN       NaN         0     False     False
# 3984      NaN      NaN      NaN       NaN         0     False     False
#
#       FIELD_49  FIELD_50  FIELD_51  FIELD_52  FIELD_53  FIELD_54  FIELD_55  \
# 1         True     29.77    17.561    30.955    31.171       0.0      0.04
# 2         True     29.77    56.512    30.955    31.171       0.0      0.16
# 3        False       NaN       NaN       NaN       NaN       NaN       NaN
# 4         True     29.77    13.789    30.955    31.171       0.0      0.03
# 6         True     29.77     4.413    30.955    31.171       0.0      0.00
# ...        ...       ...       ...       ...       ...       ...       ...
# 242       True       NaN       NaN       NaN       NaN       NaN       NaN
# 437       True       NaN       NaN       NaN       NaN       NaN       NaN
# 684       True       NaN       NaN       NaN       NaN       NaN       NaN
# 1679      True       NaN       NaN       NaN       NaN       NaN       NaN
# 3984      True       NaN       NaN       NaN       NaN       NaN       NaN
#
#       FIELD_56  FIELD_57
# 1          0.0       0.0
# 2          0.0       0.0
# 3          NaN       NaN
# 4          0.0       0.0
# 6          0.0       0.0
# ...        ...       ...
# 242        NaN       NaN
# 437        NaN       NaN
# 684        NaN       NaN
# 1679       NaN       NaN
# 3984       NaN       NaN
#
# [23332 rows x 64 columns]

# %%
preProce.cl_FIELD_12()

# %%
preProce.dataset.FIELD_12.value_counts()
# Out:
# 0.0    16650
# 1.0       71
# Name: FIELD_12, dtype: int64
