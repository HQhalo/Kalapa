# %%
from loadData import *
from preProcessing import *
pd.set_option("max_columns",None)
pd.set_option("max_rows",100)
from sklearn.preprocessing import LabelEncoder

# %%
train= load_train_dataset()
test = load_test_dataset()
# Out:
# /Users/hq/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
preProc = PreProcessing()
preProc.fit(train,dropNa = True)
preProc.transform()
# Out:
#       FIELD_18  FIELD_19  FIELD_20  FIELD_23  FIELD_25  FIELD_26  FIELD_27  \
# 1          1.0       2.0       2.0       1.0       2.0       1.0       1.0
# 2          2.0       1.0       1.0       1.0       1.0       2.0       1.0
# 3          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4          1.0       2.0       2.0       1.0       2.0       1.0       1.0
# 6          1.0       2.0       1.0       1.0       2.0       1.0       1.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 242        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 437        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 684        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1679       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3984       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
for i in preProc.dataset.columns:
    print("_____________________")
    print(preProc.dataset[i].value_counts(dropna = False))
# Out:
# _____________________
# 1.0    11545
# 2.0     8777
# NaN     3010
# Name: FIELD_18, dtype: int64
# _____________________
# 1.0    15337
# 2.0     4985
# NaN     3010
# Name: FIELD_19, dtype: int64
# _____________________
# 1.0    17190
# 2.0     3132
# NaN     3010
# Name: FIELD_20, dtype: int64
# _____________________
# 1.0    20322
# NaN     3010
# Name: FIELD_23, dtype: int64
# _____________________
# 1.0    15907
# 2.0     4415
# NaN     3010
# Name: FIELD_25, dtype: int64
# _____________________
# 1.0    12301
# 2.0     8021
# NaN     3010
# Name: FIELD_26, dtype: int64
# _____________________
# 1.0    20124
# NaN     3010
# 2.0      198
# Name: FIELD_27, dtype: int64
# _____________________
# 1.0    20124
# NaN     3010
# 2.0      198
# Name: FIELD_28, dtype: int64
# _____________________
# 1.0    16717
# NaN     6614
# 2.0        1
# Name: FIELD_29, dtype: int64
# _____________________
# 1.0    10499
# NaN     7135
# 2.0     5698
# Name: FIELD_30, dtype: int64
# ...

# %%
preProc.dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23332 entries, 1 to 3984
# Data columns (total 63 columns):
# FIELD_18     20322 non-null float64
# FIELD_19     20322 non-null float64
# FIELD_20     20322 non-null float64
# FIELD_23     20322 non-null float64
# FIELD_25     20322 non-null float64
# FIELD_26     20322 non-null float64
# FIELD_27     20322 non-null float64
# FIELD_28     20322 non-null float64
# FIELD_29     16718 non-null float64
# FIELD_30     16197 non-null float64
# FIELD_31     16083 non-null float64
# FIELD_36     20317 non-null float64
# FIELD_37     20319 non-null float64
# FIELD_38     20322 non-null float64
# province     17182 non-null float64
# district     17151 non-null float64
# FIELD_8      20322 non-null float64
# FIELD_10     20322 non-null float64
# FIELD_11     20288 non-null float64
# FIELD_13     20300 non-null float64
# FIELD_17     3691 non-null float64
# FIELD_24     499 non-null float64
# FIELD_39     23332 non-null int64
# ...

# %%
# from sklearn.preprocessing import LabelEncoder
# lbEncoder = LabelEncoder()

# %%
def convert_bool(val):
        if val == True:
            return True
        elif val == False:
            return False
        return np.nan
preProc.dataset.FIELD_18.astype("int32")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-356e370e5615> in <module>
#       5             return False
#       6         return np.nan
# ----> 7 preProc.dataset.FIELD_18.astype("int32")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
# ...

# %%
encode_cols = ["province","district","FIELD_8","FIELD_11","FIELD_13","FIELD_24","FIELD_39",
        "FIELD_40","FIELD_41","FIELD_42","FIELD_44"]  
encode_df = train[encode_cols]

# %%
encode_df = encode_df.apply(EncodeLabelNan().fit_transform)
df_drop = train.drop(encode_cols,axis = 1)

# %%
pd.concat([encode_df,df_drop],axis=1)
